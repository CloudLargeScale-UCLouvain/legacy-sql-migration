# %%
# !curl -sSL -o ./argo https://github.com/argoproj/argo/releases/download/v2.7.6/argo-linux-amd64
# !chmod +x ./argo

# %%
from pymongo import MongoClient
client = MongoClient("manager-mongo-manager")
db_names = client.list_database_names()
for db_name in db_names:
    if "camundaa" in db_name:
        print(db_name)
        client.drop_database(db_name)

# %%
from importnb import Notebook
with __import__('importnb').Notebook():
    from scripts import *

# %%
def launch_workflow(wf, scenario, additional_parameters={}):
    param_str = ""
    for k in additional_parameters.keys():
        param_str += "-p {}={} ".format(str(k).replace("!","."), str(additional_parameters[k]).replace("!","."))
        
    run_command("./argo submit --wait {} -n default -f {} {} ".format(wf, scenario, param_str))

# %% [markdown]
# # Camunda

# %%
logall="false"

# %% [markdown]
# # Camunda

# %%
logall=False
launch_workflow("wf-camunda-fdw.yaml", "final2805/camunda-nofdw-1O.yaml", {"pod-placement":"true", "logall":logall, "xp-name":"final0506-camunda-nofdw-1O"})
launch_workflow("wf-camunda-fdw.yaml", "final2805/camunda-fdw-1O1M.yaml", {"pod-placement":"true", "logall":logall, "xp-name":"final0506-camunda-fdw-1O1M"})
launch_workflow("wf-camunda-fdw.yaml", "final2805/camunda-fdw-1O.yaml", {"pod-placement":"true", "logall":logall, "xp-name":"final0506-camunda-fdw-1O"})
launch_workflow("wf-camunda-fdw.yaml", "final2805/camunda-fdw-1M.yaml", {"pod-placement":"true", "logall":logall, "xp-name":"final0506-camunda-fdw-1M"})
launch_workflow("wf-camunda-fdw.yaml", "final2805/camunda-nofdw-2O.yaml", {"pod-placement":"true", "logall":logall, "xp-name":"final0506-camunda-nofdw-2O"})
# Out:
# ./argo submit --wait wf-camunda-fdw.yaml -n default -f final2805/camunda-nofdw-1O.yaml -p pod-placement=true -p logall=False -p xp-name=final0506-camunda-nofdw-1O
# ./argo submit --wait wf-camunda-fdw.yaml -n default -f final2805/camunda-nofdw-1O.yaml -p pod-placement=true -p logall=False -p xp-name=final0506-camunda-nofdw-1O
# Log 0 - 2020-06-05 12:57:42 : Name:                camunda-fdw-xprk2
# Log 0 - 2020-06-05 12:57:42 : Namespace:           default
# Log 0 - 2020-06-05 12:57:42 : ServiceAccount:      default
# Log 0 - 2020-06-05 12:57:42 : Status:              Pending
# Log 0 - 2020-06-05 12:57:42 : Created:             Fri Jun 05 12:57:42 +0000 (now)
# Log 0 - 2020-06-05 12:57:42 : Parameters:
# Log 0 - 2020-06-05 12:57:42 : pod-placement:     true
# Log 0 - 2020-06-05 12:57:42 : logall:            False
# Log 0 - 2020-06-05 12:57:42 : xp-name:           final0506-camunda-nofdw-1O
# Log 0 - 2020-06-05 12:57:42 : chart:             camunda
# ...

# %% [markdown]
# # Moodle

# %%
launch_workflow("wf-moodle-fdw.yaml", "final2805/moodle-nofdw-1O.yaml", {"pod-placement":"true", "logall":logall, "xp-name":"final0406-moodle-nofdw-1O"})
launch_workflow("wf-moodle-fdw.yaml", "final2805/moodle-fdw-1O1M.yaml", {"pod-placement":"true", "logall":logall, "xp-name":"final0406-moodle-fdw-1O1M"})
launch_workflow("wf-moodle-fdw.yaml", "final2805/moodle-fdw-1O.yaml", {"pod-placement":"true", "logall":logall, "xp-name":"final0406-moodle-fdw-1O"})
launch_workflow("wf-moodle-fdw.yaml", "final2805/moodle-fdw-1M.yaml", {"pod-placement":"true", "logall":logall, "xp-name":"final0406-moodle-fdw-1M"})
launch_workflow("wf-moodle-fdw.yaml", "final2805/moodle-nofdw-2O.yaml", {"pod-placement":"true", "logall":logall, "xp-name":"final0406-moodle-nofdw-2O"})
# Out:
# ./argo submit --wait wf-moodle-fdw.yaml -n default -f final2805/moodle-nofdw-1O.yaml -p pod-placement=true -p logall=false -p xp-name=final0406-moodle-nofdw-1O
# ./argo submit --wait wf-moodle-fdw.yaml -n default -f final2805/moodle-nofdw-1O.yaml -p pod-placement=true -p logall=false -p xp-name=final0406-moodle-nofdw-1O
# Log 0 - 2020-06-05 00:51:38 : Name:                moodle-fdw-j7txf
# Log 0 - 2020-06-05 00:51:38 : Namespace:           default
# Log 0 - 2020-06-05 00:51:38 : ServiceAccount:      default
# Log 0 - 2020-06-05 00:51:38 : Status:              Pending
# Log 0 - 2020-06-05 00:51:38 : Created:             Fri Jun 05 00:51:38 +0000 (now)
# Log 0 - 2020-06-05 00:51:38 : Parameters:
# Log 0 - 2020-06-05 00:51:38 : pod-placement:     true
# Log 0 - 2020-06-05 00:51:38 : logall:            false
# Log 0 - 2020-06-05 00:51:38 : xp-name:           final0406-moodle-nofdw-1O
# Log 0 - 2020-06-05 00:51:38 : chart:             moodle
# ...
